# %%
import random
import string

# %% [markdown]
# 1. Write a Python program to generate a random color hex, a random alphabetical string, random value between two integers (inclusive) and a random multiple of 7 between 0 and 70. Use random.randint()

# %%
color_hex = '#' + str(hex(random.randint(0,16777215)))[2:]

s = ""

for i in range(random.randint(1, 30)):
    s += random.choice(string.ascii_letters)
    
randval = (random.randint(0, 5))

randmult = (random.randint(0, 10) * 7)

print(color_hex, s, randval, randmult)
# Out:
# #3ec5 dIRJyatpzipCUWDxIEiHiMLCUqH 3 63

# %% [markdown]
# 2. Write a Python program to select a random element from a list

# %%
random.choice([0,2,4,'a','b'])
# Out:
# 'a'

# %% [markdown]
# 3. Write a Python program to generate a random alphabetical character, alphabetical string and alphabetical string of a fixed length. Use random.choice()

# %%
randalpha = random.choice(string.ascii_letters)

s1 = ''
for i in range(random.randint(1, 20)):
    s1 += random.choice(string.ascii_letters)
    
s2 = ''
for i in range(0,5):
    s2 += random.choice(string.ascii_letters)

print(randalpha, s1, s2)
# Out:
# w klMPGpvAQfwWOy sYbrV

# %% [markdown]
# 4. Write a Python program to generate a float between 0 and 1. Use random.random()

# %%
random.uniform(0,1)
# Out:
# 0.6445051191729804

# %% [markdown]
# 6. Write a Python program to shuffle the elements of a given list. Use random.shuffle()

# %%
l = [1,5,4,6,7,4,3]

random.shuffle(l)

l
# Out:
# [7, 1, 4, 5, 6, 3, 4]

# %% [markdown]
# 7. Write a Python program to generate a random float within a specific range. Use random.uniform()

# %%
random.uniform(0,2)
# Out:
# 0.04249590258902147

# %% [markdown]
# 8. Write a Python program to create a list of random integers and randomly select multiple items from the said list. Use random.sample()

# %%
l = []

for x in range(0,10):
    l.append(int(random.uniform(1, 100)))
    
random.sample(l, 5)
# Out:
# [81, 34, 66, 3, 62]
