# %%
import math
import random

# %% [markdown]
# __1) Write a function named capital_indexes. The function takes a single parameter, which is a string. Your function should return a list of all the indexes in the string that have capital letters. For example, calling capital_indexes("HeLlO") should return the list [0, 2, 4].__

# %%
word = "HeLlO"

word.find('e')
# Out:
# 1

# %%
capitals = []

for x in word:
    if x == x.upper():
        capitals.append(word.find(x))
        
capitals
# Out:
# [0, 2, 4]

# %%
def capital_indexes(word):
    capitals = []
    for x in word:
        if x == x.upper():
            capitals.append(word.find(x))
    return capitals

capital_indexes(word)
# Out:
# [0, 2, 4]

# %%
enum_list = []

for place, letter in enumerate(word):
    enum_list.append([place, letter])

enum_list
# Out:
# [[0, 'H'], [1, 'e'], [2, 'L'], [3, 'l'], [4, 'O']]

# %%
capital_places = []

for place, letter in enumerate(word):
    if letter == letter.upper():
        capital_places.append(place)

capital_places
# Out:
# [0, 2, 4]

# %%
def capital_indexes2(word):
    capital_places = []
    for place, letter in enumerate(word):
        if letter == letter.upper():
            capital_places.append(place)
    return capital_places

capital_indexes2('TeST')
# Out:
# [0, 2, 3]

# %% [markdown]
# __2) Write a function named mid that takes a string as its parameter. Your function should extract and return the middle letter.
# If there is no middle letter, your function should return the empty string.
# For example, mid("abc") should return "b" and mid("aaaa") should return "".__

# %%
def mid(word):
    if len(word) % 2 == 0:
        return ""
    else:
        mid_pos = math.floor(len(word) / 2)
        return word[mid_pos]

# %%
mid('python')
# Out:
# ''

# %%
mid('kites')
# Out:
# 't'

# %%
word = 'rat'
word[1]
# Out:
# 'a'

# %%
math.floor(3.5)
# Out:
# 3

# %% [markdown]
# __3) Write a function named online_count that takes one parameter.
# The parameter is a dictionary that maps from strings of names to the string "online" or "offline", as seen above.
# Your function should return the number of people who are online.__

# %%
statuses = {
    "Alice": "online",
    "Bob": "offline",
    "Eve": "online",
}

# %%
offline_count = 0
online_count = 0

for x in statuses:
    if statuses[x] == 'online':
        online_count += 1
    else:
        offline_count += 1

online_count
# Out:
# 2

# %%
def online_count(statuses):
    online_count = 0
    for x in statuses:
        if statuses[x] == 'online':
            online_count += 1
    return online_count

online_count(statuses)
# Out:
# 2

# %% [markdown]
# __Define a function, random_number, that takes no parameters. The function must generate a random integer between 1 and 100, both inclusive, and return it.__

# %%
def random_number():
    return random.randint(1, 100)

random_number()
# Out:
# 59

# %% [markdown]
# __4) Write a function named only_ints that takes two parameters.
# Your function should return True if both parameters are integers, and False otherwise.__

# %%
def only_ints(p1, p2):
    if type(p1) == int and type(p2) == int:
        return True
    else:
        return False

only_ints(2,'a')
# Out:
# False

# %%
only_ints(2, 3)
# Out:
# True

# %% [markdown]
# __5) Define a function named double_letters that takes a single parameter. The parameter is a string. Your function must return True if there are two identical letters in a row in the string, and False otherwise.__

# %%
for place, letter in enumerate(string[:len(string)-1]):
    if letter == string[place + 1]:
        print(place, letter)
# Out:
# 1 p

# %%
def double_letters(string):
    answer = False
    for place, letter in enumerate(string[:len(string)-1]):
        if letter == string[place + 1]:
            answer = True
    return answer

double_letters('apple')
# Out:
# True

# %%
double_letters('card')
# Out:
# False

# %% [markdown]
# __6) Write a function named add_dots that takes a string and adds "." in between each letter. For example, calling add_dots("test") should return the string "t.e.s.t". Then, below the add_dots function, write another function named remove_dots that removes all dots from a string. For example, calling remove_dots("t.e.s.t") should return "test". If both functions are correct, calling remove_dots(add_dots(string)) should return back the original string for any string.__

# %%
word = 'test'

word = word.replace('','.')

word = word[1:-1]

word
# Out:
# 't.e.s.t'

# %%
def add_dots(string):
    string = string.replace('','.')
    string = string[1:-1]
    return string
    
add_dots('apple')
# Out:
# 'a.p.p.l.e'

# %%
word2 = '.m.a.n.'

word2 = word2.replace('.','')

word2
# Out:
# 'man'

# %%
def remove_dots(string):
    string = string.replace('.', '')
    return string

# %%
remove_dots('.m.a.n..')
# Out:
# 'man'

# %%
remove_dots(add_dots('test'))
# Out:
# 'test'

# %% [markdown]
# __#7 Define a function named count that takes a single parameter. The parameter is a string. The string will contain a single word divided into syllables by hyphens.__

# %%
word = 'ho-tel'

word.split('-')
# Out:
# ['ho', 'tel']

# %%
len(word.split('-'))
# Out:
# 2

# %%
def count(word):
    return len(word.split('-'))

count('met-a-phor')
# Out:
# 3

# %% [markdown]
# __# 8 Write a function named is_anagram that takes two strings as its parameters. Your function should return True if the strings are anagrams, and False otherwise.__

# %%
words = ['apple', 'papple', 'car']

words.sort()

words
# Out:
# ['apple', 'car', 'papple']

# %%
word = 'apple'

sorted(word)
# Out:
# ['a', 'e', 'l', 'p', 'p']

# %%
def is_anagram(w1, w2):
    if sorted(w1) == sorted(w2):
        return True
    else:
        return False

# %%
is_anagram('sheep', 'santa')
# Out:
# False

# %%
is_anagram('sheep', 'peesh')
# Out:
# True

# %% [markdown]
# __# 9 Write a function that takes a list of lists and flattens it into a one-dimensional list. Name your function flatten. It should take a single parameter and return a list.__

# %%
lists = [[1, 2], [3, 4]]

# %%
flat_list = []

for l in lists:
    for i in l:
        flat_list.append(i)

flat_list
# Out:
# [1, 2, 3, 4]

# %%
def flatten(l_of_lists):
    flat_list = []
    for l in l_of_lists:
        for i in l:
            flat_list.append(i)
    return flat_list

# %%
flatten([[1, 2], [3, 4]])
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# __#10 Define a function named largest_difference that takes a list of numbers as its only parameter. Your function should compute and return the difference between the largest and smallest number in the list.__

# %%
nums = [1, 2, 3, 4]

max(nums) - min(nums)
# Out:
# 3

# %%
def largest_difference(numbers):
    return max(numbers) - min(numbers)

# %%
largest_difference(nums)
# Out:
# 3

# %% [markdown]
# __#11 Define a function named div_3 that returns True if its single integer parameter is divisible by 3 and False otherwise.__

# %%
def div_3(num):
    return num % 3 == 0

# %%
div_3(3)
# Out:
# True

# %%
div_3(4)
# Out:
# False

# %% [markdown]
# __#12 Your task is to write a function that can translate from strings of length 2 to a tuple (row, column). Name your function get_row_col; it should take a single parameter which is a string of length 2 consisting of an uppercase letter and a digit. For example, calling get_row_col("A3") should return the tuple (2, 0) because A3 corresponds to the row at index 2 and column at index 0 in the board.__

# %%
board = [
    ["X", "O", "X"],
    [" ", " ", " "],
    ["O", " ", " "],
]

# %%
board
# Out:
# [['X', 'O', 'X'], [' ', ' ', ' '], ['O', ' ', ' ']]

# %%
board_dict = {'A' : 0, 'B' : 1, 'C' : 2, '1' : 0, '2' : 1, '3' : 2}

# %%
board_dict
# Out:
# {'A': 0, 'B': 1, 'C': 2, '1': 0, '2': 1, '3': 2}

# %%
board_dict['A']
# Out:
# 0

# %%
sample_coord = 'A3'

for x in sample_coord:
    print(x)
# Out:
# A
# 3

# %%
list(sample_coord)
# Out:
# ['A', '3']

# %%
def get_row_col(coords):
    board_dict = {'A' : 0, 'B' : 1, 'C' : 2, '1' : 0, '2' : 1, '3' : 2}
    coords = list(coords)
    return (board_dict[coords[1]],board_dict[coords[0]])

get_row_col('A3')
# Out:
# (2, 0)

# %% [markdown]
# __#13 Write a function named palindrome that takes a single string as its parameter. Your function should return True if the string is a palindrome, and False otherwise.__

# %%
word = 'hihello'

word[::-1]
# Out:
# 'ollehih'

# %%
def palindrome(word):
    return word[::-1] == word

# %%
palindrome('hello')
# Out:
# False

# %%
palindrome('atoyota')
# Out:
# True

# %% [markdown]
# __#14 Define a function named up_down that takes a single number as its parameter. Your function return a tuple containing two numbers; the first should be one lower than the parameter, and the second should be one higher.__

# %%
def up_down(num):
    return ((num - 1), (num + 1))

up_down(3)
# Out:
# (2, 4)

# %% [markdown]
# __#15 Define a function named consecutive_zeros that takes a single parameter, which is the string of zeros and ones. Your function should return the largest number of consecutive 0's__

# %%
bi = '010000111100101010011'

bi.split('1')
# Out:
# ['0', '0000', '', '', '', '00', '0', '0', '00', '', '']

# %%
lengths = [len(x) for x in bi.split('1')]

lengths
# Out:
# [1, 4, 0, 0, 0, 2, 1, 1, 2, 0, 0]

# %%
max(lengths)
# Out:
# 4

# %%
def consecutive_zeros(string):
    return max([len(x) for x in string.split('1')])

# %%
consecutive_zeros('010000111100101010011')
# Out:
# 4

# %% [markdown]
# __#16 Define a function named all_equal that takes a list and checks whether all elements in the list are the same.__

# %%
def all_equal(l):
    if len(set(l)) > 1:
        return False
    else:
        return True

# %%
all_equal([1,1,1])
# Out:
# True

# %%
all_equal([1,1,2])
# Out:
# False

# %% [markdown]
# __#17 Define a function named triple_and that takes three parameters and returns True only if they are all True and False otherwise.__

# %%
True + False + True
# Out:
# 2

# %%
def triple_and(a, b, c):
    return a and b and c

# %%
triple_and(True, False, True)
# Out:
# False

# %%
triple_and(True, True, True)
# Out:
# True

# %%
triple_and(1 + 2 == 4, True, True)
# Out:
# False

# %% [markdown]
# __#18 Define a function named convert that takes a list of numbers as its only parameter and returns a list of each number converted to a string. For example, the call convert([1, 2, 3]) should return ["1", "2", "3"]. What makes this tricky is that your function body must only contain a single line of code.__

# %%
l = [1,2,3]

[int(num) for num in l]
# Out:
# [1, 2, 3]

# %%
def convert(l):
    return [str(num) for num in l]

# %%
convert(l)
# Out:
# ['1', '2', '3']

# %% [markdown]
# __#19 The built-in zip function "zips" two lists. Write your own implementation of this function. Define a function named zap. The function takes two parameters, a and b. These are lists. Your function should return a list of tuples. Each tuple should contain one item from the a list and one from b. You may assume a and b have equal lengths.__

# %%
a = [0, 1]
b = [2, 3]

zap_list = []

for i in range(0,len(a)):
        zap_list.append((a[i], b[i]))
        
zap_list
# Out:
# [(0, 2), (1, 3)]

# %%
def zap(a, b):
    zap_list = []
    for i in range(0,len(a)):
        zap_list.append((a[i], b[i]))
    return zap_list

# %%
zap(a,b)
# Out:
# [(0, 2), (1, 3)]

# %% [markdown]
# __#20 Write a function named validate that takes code represented as a string as its only parameter.__
#
# Your function should check a few things:
#
# the code must contain the def keyword
# otherwise return "missing def"
#
# the code must contain the : symbol
# otherwise return "missing :"
#
# the code must contain ( and ) for the parameter list
# otherwise return "missing paren"
#
# the code must not contain ()
# otherwise return "missing param"
#
# the code must contain four spaces for indentation
# otherwise return "missing indent"
#
# the code must contain validate
# otherwise return "wrong name"
#
# the code must contain a return statement
# otherwise return "missing return"
#
# If all these conditions are satisfied, your code should return True.
#
# __Here comes the twist: your solution must return True when validating itself.__

# %%
def validate(s):
    p = '(' + ')'
    if "def" not in s:
        return "missing def"
    elif ":" not in s:
        return "missing :"
    elif "(" not in s or ")" not in s:
        return "missing paren"
    elif p in s:
        return "missing param"
    elif "    " not in s:
        return "missing indent"
    elif "validate" not in s:
        return "wrong name"
    elif "return" not in s:
        return "missing return"
    else:
        return True

# %%
p = '(' + ')'

p
# Out:
# '()'

# %%
validate('hi')
# Out:
# 'missing def'

# %%
validate('def')
# Out:
# True

# %%
validate('not def')
# Out:
# True

# %% [markdown]
# __#21 Define a function named list_xor. Your function should take three parameters: n, list1 and list2. Your function must return whether n is exclusively in list1 or list2. In other words, if n is in both lists or in none of the lists, return False. If n is in only one of the lists, return True.__

# %%
def list_xor(n, list1, list2):
    if (n in list1 and n in list2) or (n not in list1 and n not in list2):
        return False
    else:
        return True

# %%
list_xor(1, [1,2], [2,3])
# Out:
# True

# %%
list_xor(1, [1,2], [1,3])
# Out:
# False

# %% [markdown]
# __#22 Define a function param_count that takes a variable number of parameters. The function should return the number of arguments it was called with.__

# %%
def param_count(*arg):
    return arg

param_count(1,3)
# Out:
# (1, 3)

# %%
param_count()
# Out:
# ()

# %%
def param_count(*arg):
    return len(arg)

# %%
param_count()
# Out:
# 0

# %%
param_count(1,2,3)
# Out:
# 3

# %% [markdown]
# __#23 Write a function named format_number that takes a non-negative number as its only parameter. Your function should convert the number to a string and add commas as a thousands separator.__

# %%
def format_number(num):
    return str("{:,}".format(num))

# %%
format_number(123)
# Out:
# '123'

# %%
format_number(1234)
# Out:
# '1,234'

# %%
format_number(12344523542)
# Out:
# '12,344,523,542'
