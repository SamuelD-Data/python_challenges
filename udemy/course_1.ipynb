# %% [markdown]
# Considering the string below, what is the character or substring returned by my_string[19] ?
#
# my_string = "a0:12:90:00:80:43"

# %%
my_string = "a0:12:90:00:80:43"

my_string[19]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-6b8847c6c5df> in <module>
#       1 my_string = "a0:12:90:00:80:43"
#       2
# ----> 3 my_string[19]
#
# IndexError: string index out of range

# %% [markdown]
# Considering the string below, what is the character or substring returned by my_string[4:7] ?
#
# my_string = "a0:12:90:00:80:43"

# %%
my_string = "a0:12:90:00:80:43"

my_string[4:7]
# Out:
# '2:9'

# %% [markdown]
# Considering the string below, what is the character or substring returned by my_string[:-4] ?
#
#
# my_string = "a0:12:90:00:80:43"

# %%
my_string = "a0:12:90:00:80:43"

my_string[:-4]
# Out:
# 'a0:12:90:00:8'

# %% [markdown]
# Insert a '-' to so that only the letter R is returned

# %%
my_string = "I love programming in Python more than Ruby or Perl"

print(my_string[-12])
# Out:
# R

# %% [markdown]
# Write a slice to print 0:00: from "a0:12:90:00:80:43"

# %%
my_string = "a0:12:90:00:80:43"

print(my_string[7:12])
# Out:
# 0:00:

# %% [markdown]
# Write code to print 90:00 from "a0:12:90:00:80:43" using negative indexes

# %%
my_string = "a0:12:90:00:80:43"

print(my_string[-11:-6])
# Out:
# 90:00
