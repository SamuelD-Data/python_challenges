# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import networkx as nx
import math

from math import pi
from matplotlib_venn import venn2, venn2_circles
from wordcloud import WordCloud

import circlify
import warnings
warnings.filterwarnings("ignore")

# %%
# creating series of average weapon durability, sorted alphabetically by hero class name
weapons_dur = weapons.groupby('name_prime_hero_class').mean()['durability'].sort_values()
weapons_dur.index = weapons_dur.index.str.title()

# %%
df = pd.DataFrame([[.59,.57,.56],[.66, .64, .61]], ['pre', 'post'] )

df.columns = ['neutral', 'positive', 'negative']

# %%
df
# Out:
#       neutral  positive  negative
# pre      0.59      0.57      0.56
# post     0.66      0.64      0.61

# %%
# creating list of colors for hero class colors
#dur_colors = color_mapper(weapons_dur.index)

# plotting horizontal lines (stems of lollipops)
#xtick_range = range(0,len(df.index))
#plt.vlines(x = xtick_range, ymin = 0, ymax = df, color = 'b')

# plotting dots ("candy" portion of lollipop) that reflect average weapon durability for respective class
plt.scatter(df, s = 300, edgecolors= 'b')

# configuring ticks, axis labels, etc.
#plt.xticks(xtick_range, df.index, fontsize = 15)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('Hero Class', fontsize = 20, labelpad = 20)
plt.ylabel('Durability', fontsize = 20, labelpad = 20)
plt.title('Average Weapon Durability by Class', fontsize = 25)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-35d3f3e83af6> in <module>
#       7
#       8 # plotting dots ("candy" portion of lollipop) that reflect average weapon durability for respective class
# ----> 9 plt.scatter(df, s = 300, edgecolors= 'b')
#      10
#      11 # configuring ticks, axis labels, etc.
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
df = pd.DataFrame({'neutral': [.59, .66], 'positive': [.57, .64], 'negative':[.56,.61]}, index = [0, 1])

df
# Out:
#    neutral  positive  negative
# 0     0.59      0.57      0.56
# 1     0.66      0.64      0.61

# %%
x = np.linspace(-1, 1)
y1 = .59
y2 = .57

#plt.figure(num = 3, figsize(8,5))
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-a231fbb8d97c> in <module>
#       4
#       5 #plt.figure(num = 3, figsize(8,5))
# ----> 6 plt.plot(x, y1)
#       7 plt.plot(x, y2)
#       8 plt.show()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (1,)
